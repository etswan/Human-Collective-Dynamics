# %% [markdown]
# This project seeks to model human collective dynamics using existing multivariate data to investigate the role of collective dynamics and distributed cognition in learning, resiliency, and altered states of consciousness.

# %% [markdown]
# # Modeling Methodology Sources and Potential Frameworks

# %% [markdown]
# **SC** A modular software suite for composing continuously-evolving responsive environments Brandon Mechtley, Todd Ingalls, Julian Stein, Connor Rawls & Sha Xin Wei Arizona State University, Tempe, USA
#
# **EEG Music Mapping** Ceccato, C., Pruss, E., Vrins, A., Prinsen, J., & Alimardani, M. (2023). BrainiBeats: A dual brain-computer interface for musical composition using inter-brain synchrony and emotional valence. In A. Schmidt, K. Väänänen, T. Goyal, P. O. Kristensson, & A. Peters (Eds.), Extended Abstracts of the 2023 CHI Conference on Human Factors in Computing Systems (pp. 1–7). ACM. https://doi.org/10.1145/3544549.3585910
#
# **CHARM**
# Deco, G., Sanz Perl, Y., & Kringelbach, M. L. (2025). Complex harmonics reveal low-dimensional manifolds of critical brain dynamics.Physical Review. E,111(1), Article 014410. https://doi.org/10.1103/PhysRevE.111.014410
#
# **SOM**
# Murakami, H., Feliciani, C., Nishiyama, Y., & Nishinari, K. (2021). Mutual anticipation can contribute to self-organization in human crowds. Science Advances, 7(12). https://doi.org/10.1126/sciadv.abe7758
#
# **HCM**
# Brooker, J. S., van Leeuwen, E. J. C., & Clay, Z. (2026). Social structure as a form of collective intelligence: a new framework. Philosophical Transactions of the Royal Society of London. Series B. Biological Sciences, 381(1948). https://doi.org/10.1098/rstb.2024.0443
#
# Schmid, G., & Braun, D. A. (2025). Human intergroup coordination in a hierarchical multi-agent sensorimotor task arises from concurrent co-optimization. Scientific Reports, 15(1), Article 14849. https://doi.org/10.1038/s41598-025-97574-3
#
# Tump, A. N., Deffner, D., Pleskac, T. J., Romanczuk, P., & M. Kurvers, R. H. J. (2024). A Cognitive Computational Approach to Social and Collective Decision-Making. Perspectives on Psychological Science, 19(2), 538–551. https://doi.org/10.1177/17456916231186964
#
# Yadav, C. K. (2026). Least ranked human individuals exhibit scale free behavioral responses in hierarchical social systems. BioSystems, 259, Article 105678. https://doi.org/10.1016/j.biosystems.2025.105678
#
# **Deep Dynamical Systems**
# Gorman, J. C., Dunbar, T. A., Grimm, D., & Gipson, C. L. (2017). Understanding and Modeling Teams As Dynamical Systems. Frontiers in Psychology, 8, 1053. https://doi.org/10.3389/fpsyg.2017.01053
#
# Jaffe, P. I., Poldrack, R. A., Schafer, R. J., & Bissett, P. G. (2023). Modelling human behaviour in cognitive tasks with latent dynamical systems. Nature Human Behaviour, 7(6), 986–1000. https://doi.org/10.1038/s41562-022-01510-8
#
# Sgobba, T., & International Association for the Advancement of Space Safety. (2018). Space safety and human performance. Butterworth-Heinemann.
#
# Thieu, T., & Melnik, R. (2025). Modelling the Behavior of Human Crowds as Coupled Active-passive Dynamics of Interacting Particle Systems. Methodology and Computing in Applied Probability, 27(1), Article 15. https://doi.org/10.1007/s11009-025-10139-9
#
# Wang, M., & Li, J. (2024). Interpretable predictions of chaotic dynamical systems using dynamical system deep learning. Scientific Reports, 14(1), Article 3143. https://doi.org/10.1038/s41598-024-53169-y
#
# - **Langevin equation** Eddakoun, A., Hader, A., Tarras, I., Bakkasi, I., Tanasehte, M., Moultif, R., Eddahby, M., & Bachiri, A. el. (2025). Simulating and analyzing the dynamics of collective movement with elastic interactions and leadership influence. Physical Review. E, 112(1), Article 014130. https://doi.org/10.1103/2p2h-vz38
# - Graph-theoretic representation of mutual influence loops over time using directed interaction graphs, multi-agent Deep Variational Autoencoders (DyVA), Kuramoto coupled oscillators.
#
# **Multiplex Networks**
# Nakis, N., Lehmann, S., Christakis, N. A., & Mørup, M. (2026). Modeling roles and trade-offs in multiplex networks. Nature Communications, 17(1), Article 3622. https://doi.org/10.1038/s41467-026-68896-1
#
# **Data-Driven Reduced Order Modelling**
# Noack, B. R., Pastur, L. R., & Cornejo Maceda, G. Y. (2025). Cluster globally, model locally: clusterwise modeling of nonlinear dynamics. Acta Mechanica Sinica, 41(8), Article 324545. https://doi.org/10.1007/s10409-024-24545-x
#
# **Agent-Based MOdelling**
# Zhong, M., Miller, J., & Maggioni, M. (2020). Data-driven discovery of emergent behaviors in collective dynamics. Physica. D, 411, Article 132542. https://doi.org/10.1016/j.physd.2020.132542

# %% [markdown]
# # Potential Data Sources

# %% [markdown]
# Chabin, T., Gabriel, D., Comte, A., & Pazart, L. (2022). Audience Interbrain Synchrony During Live Music Is Shaped by Both the Number of People Sharing Pleasure and the Strength of This Pleasure. Frontiers in Human Neuroscience, 16, 855778. https://doi.org/10.3389/fnhum.2022.855778
#
# Francis, M., Markus, A., Stuhr-Wulff, F., & Shamay-Tsoory, S. (2026). Shaping inter-brain plasticity: A feasibility study of enhancing inter-brain synchrony with dyadic neurofeedback. iScience, 29(3), Article 114894. https://doi.org/10.1016/j.isci.2026.114894
#
# Gamliel, H. N., Nevat, M., Probolovski, H. Z. G., Karklinsky, M., Han, S., & Shamay-Tsoory, S. G. (2021). Inter-group conflict affects inter-brain synchrony during synchronized movements. NeuroImage (Orlando, Fla.), 245, Article 118661. https://doi.org/10.1016/j.neuroimage.2021.118661
#
# Hu, Y., Pan, Y., Shi, X., Cai, Q., Li, X., & Cheng, X. (2018). Inter-brain synchrony and cooperation context in interactive decision making. Biological Psychology, 133, 54–62. https://doi.org/10.1016/j.biopsycho.2017.12.005
#
# Johnson, G. L., Peterson, B. J., Ingalls, T., & Wei, S. X. (2018). Lanterns: An Enacted and Material Approach to Ensemble Group Activity with Responsive Media. Proceedings of the 5th International Conference on Movement and Computing, 1–4. https://doi.org/10.1145/3212721.3212848
#
# Li, R., Mayseless, N., Balters, S., & Reiss, A. L. (2021). Dynamic inter-brain synchrony in real-life inter-personal cooperation: A functional near-infrared spectroscopy hyperscanning study. NeuroImage (Orlando, Fla.), 238, Article 118263. https://doi.org/10.1016/j.neuroimage.2021.118263
#
# Maidhof, C., Müller, V., Lartillot, O., Agres, K., Bloska, J., Asano, R., Odell-Miller, H., & Fachner, J. (2023). Intra- and inter-brain coupling and activity dynamics during improvisational music therapy with a person with dementia: an explorative EEG-hyperscanning single case study. Frontiers in Psychology, 14, 1155732. https://doi.org/10.3389/fpsyg.2023.1155732
#
# Pan, Y., Novembre, G., Song, B., Zhu, Y., & Hu, Y. (2021). Dual brain stimulation enhances interpersonal learning through spontaneous movement synchrony. Social Cognitive and Affective Neuroscience, 16(1–2), 210–221. https://doi.org/10.1093/scan/nsaa080
#
# Reinero, D. A., Dikker, S., & Van Bavel, J. J. (2021). Inter-brain synchrony in teams predicts collective performance. Social Cognitive and Affective Neuroscience, 16(1–2), 43–57. https://doi.org/10.1093/scan/nsaa135
#
# Tan, S. H. J., Leuk, S. P. J., & Teo, W.-P. (2026). Inter-brain synchrony during collaborative gaming: an investigation using theta-burst stimulation at the right temporal-parietal junction. NeuroImage (Orlando, Fla.), 332, Article 121906. https://doi.org/10.1016/j.neuroimage.2026.121906
#
# Thorn, S. D., & Wei, S. X. (2019, October 10). Instruments of Articulation: Signal Processing in Live Performance. Proceedings of the 6th International Conference on Movement and Computing, Article a10. https://doi.org/10.1145/3347122.3347133
#
# Thorn, S. D., Willcox, H., & Wei, S. X. (2020). Processual and Experiential Design in Wearable Music Workshopping. Proceedings of the 7th International Conference on Movement and Computing, 1–8. https://doi.org/10.1145/3401956.3404235
#
# Vicente, U., Ara, A., & Marco-Pallarés, J. (2023). Intra- and inter-brain synchrony oscillations underlying social adjustment. Scientific Reports, 13(1), Article 11211. https://doi.org/10.1038/s41598-023-38292-6
#
# Wang, D., Ren, Y., & Chen, W. (2024). Relationship evolution shapes inter-brain synchrony in affective sharing: The role of self-expansion. Brain Structure and Function, 229(9), 2269–2283. https://doi.org/10.1007/s00429-024-02841-0
#
# Wang, Y., Zhang, Y., Jiang, Y., Yao, Y., Zhao, F., Zhang, Z., & Zheng, M. (2026). Neural mechanisms during role-playing in music psychodrama: an fNIRS Hyperscanning study. Frontiers in Psychology, 17, 1712411. https://doi.org/10.3389/fpsyg.2026.1712411
#
# Zamm, A., Palmer, C., Bauer, A.-K. R., Bleichner, M. G., Demos, A. P., & Debener, S. (2021). Behavioral and Neural Dynamics of Interpersonal Synchrony Between Performing Musicians: A Wireless EEG Hyperscanning Study. Frontiers in Human Neuroscience, 15, 717810. https://doi.org/10.3389/fnhum.2021.717810
#
# Zhou, Z., Zamm, A., Christensen, J., Rao, V., & Loehr, J. D. (2026). Attentional engagement strengthens joint agency: Evidence from intra-brain, inter-brain, and behavioural signals via EEG hyperscanning. Acta Psychologica, 266, Article 106849. https://doi.org/10.1016/j.actpsy.2026.106849
